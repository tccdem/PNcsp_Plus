# %%
import PNcsp

# %%
PNcsp.main(["Al1Co1","-out", "dev/test_data"])
# Out:
# Program Configuration
# ---------------------
# Query formula:	 Al1Co1
# Neighbor order:	 1
# Energy filter:	 0.0
# Sleep timer:	 none
# Online: 	 False
# Calculator: 	 none
# Data source: 	 OQMD
# BlockSearch: 	 False
# Relaxer: 	 False
# OutputDir: 	 dev/test_data
# CheckNew: 	 False
# Top n: 	 none
# Top c: 	 none
# Reverse: 	 False
# ---------------------
#
# Separated Formula: ['Al', 'Co']
# PNs: [82, 63]
# Ratios: [1, 1]
# PN_new_all:  [[81, 82, 83], [62, 63, 64]]
#
#
#
# exchange_dict:  {'B': ['Al'], 'Al': ['Al'], 'Ga': ['Al'], 'Hs': ['Co'], 'Co': ['Co'], 'Rh': ['Co']}
# ['B1 Hs1', 'B1 Co1', 'B1 Rh1', 'Al1 Hs1', 'Al1 Rh1', 'Ga1 Hs1', 'Co1 Ga1', 'Ga1 Rh1']
# ['B1Hs1', 'B1Co1', 'B1Rh1', 'Al1Hs1', 'Al1Rh1', 'Ga1Hs1', 'Ga1Co1', 'Ga1Rh1']
# B1 Hs1 --> no structure
# B1 Co1
# B1 Rh1
# Al1 Hs1 --> no structure
# Al1 Rh1
# Ga1 Hs1 --> no structure
# Co1 Ga1
# Ga1 Rh1
# TERMINATED SUCCESFULLY!
#
# Total Number of CIF files: 38
